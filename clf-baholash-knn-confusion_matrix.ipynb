# %%
from IPython.display import Image

# %%
Image('confisuon-matrix.jpg', width=500)

# %% [markdown]
# ## endi bizda 1-orik 0-dovcha biz hozir korishimiz mumkin 120tadan 112ta togri topibmiz orikdan dovchadan esa 90tadan 78 ta togri topibmiz munday olib qarasa model yaxshi ishlamoqda

# %% [markdown]
# # tp-true positiv (1 orik togri topilganligi)
# # tn-true negative (0 davcha togri topilganligi)
# # fp-false positave (xato hisoblaganimiz)
# # fn-false negative (dovchadan notogri hisoblaganimiz)

# %%
Image('precision-recall.jpg',width=600)

# %% [markdown]
# # precision - nechta togri aniqlaganimiz biz buni tekshirishimiz shart chunki agar meditsinada ish qilayotgan bolsak kasal odamni sog yoki teskarisini berib quyishimiz mumkin

# %% [markdown]
# # shu holat uchun presion formulasi

# %%
112 / (112+8)
# Out:
# 0.9333333333333333

# %% [markdown]
# ## demak 93%odamni togri aniqlayapmiz

# %% [markdown]
# # endi Recall aksincha

# %%
112/(112+12)
# Out:
# 0.9032258064516129

# %% [markdown]
# # F1 score bor ikkla tepadagini foizini hisoblab beradi togri ishlash

# %%
(2*0.93 * 0.9)/1.83
# Out:
# 0.9147540983606558

# %% [markdown]
# # 91% aniqlik

# %% [markdown]
# # agar biz modelda nechta odamni togri hisoblash muhim bolsa PRECISION dan

# %% [markdown]
# # Bular hozi 0 va 1 yani binary agar bular mulple bolsachi faqat matrix samiz biroz ozgaradi holos

# %%
Image('mulple-matrix.jpg', width=500)

# %% [markdown]
# # bunda formula usha faqat tp1 tp2 shunaqa qilib ozgaradi holos
