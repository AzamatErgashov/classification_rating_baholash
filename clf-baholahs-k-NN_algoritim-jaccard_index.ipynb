# %%
from IPython.display import Image

# %%
Image('Knn-asosiy-tavsiya-tizimi.jpg', width=500)

# %% [markdown]
# # K neighbor algorith

# %% [markdown]
# K - ta eng yaqin qoshnilar yani bizda data bosa oshani size rangga ajratib 2ta classga bolsa eng yaqin K ta misol 3ta eng yaqini olamiz va bizga berilgan mahsulot manashu narsa deb aytamiz

# %% [markdown]
# # Classificatisya modelni boholash

# %% [markdown]
# ## baholash deganda nimani tushunamiz bizda oriklar rangi va hajmi bor va ularni klasi bor misol qaysi orik qaysi dovcha holi pishmagan

# %% [markdown]
# ## endi bizda y-asil qiymat y-bashorat qiymatlari bor
# ## endi biz bularni farqini baholab olishimiz kerak modelimiz qanchalik aniq ishlashini bilish uchun

# %% [markdown]
# # Jaccard index

# %%
Image('jacarda-index-formulasi.jpg',width=500)

# %% [markdown]
# # Bunda A asil qiymatlar B basharat qilingan qiymatlar

# %% [markdown]
# # tepadagi A^B bu ikta malumotlardagi uxshash qiymatlarni anglatadi

# %% [markdown]
# # pasdagi yani bulishdan pasdagisi A va B qushilgani yonidagini tepada tushuntirdim

# %% [markdown]
# # hop biz uxash elementlarni 6 deb olamiz umumiy datalar 9

# %%
6/(9+9-6)
# Out:
# 0.5

# %% [markdown]
# # Javob 0.5 chiqdi yani shu malumotlar uchun jaccard index si 0.5 ekan ODATDA JACCARD
#
# # INDEX QANCHALIK KATTA BOLSA MODEL ANIQLIGI SHUNCHA BALAND BOLADI
